# %% [markdown]
# ## <span style="color:Blue">Importing Libraries

# %%
# python packages


# numpy - ( number chrunching, fast, takes less space in memory )
# pandas - (table manipulation, operation, load, data cleaning ) 80% ML Project

# matplotlib - (one of the first libray for plotting used in python)
# seaborn - (plotting, easier syntax)

# sklearn - (applying Machine Learning Algorithms)

# %%
import pandas as pd
from sklearn.mixture import GaussianMixture # Clustering(Group)

import matplotlib.pyplot as plt
plt.style.use('seaborn')

import seaborn as sns
# Out:
# <ipython-input-2-e602cfa9b92d>:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# ## <span style="color:Blue">Get Data

# %%
data = pd.read_csv('/content/Fremont.csv',index_col='Date',parse_dates=True)
data.head()
# Out:
# <ipython-input-3-2408fc6d27ce>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data = pd.read_csv('/content/Fremont.csv',index_col='Date',parse_dates=True)
#                      Fremont Bridge East Sidewalk  \
# Date
# 2012-10-03 00:00:00                           9.0
# 2012-10-03 01:00:00                           6.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           3.0
# 2012-10-03 04:00:00                           1.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2012-10-03 00:00:00                           4.0
# 2012-10-03 01:00:00                           4.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           2.0
# 2012-10-03 04:00:00                           6.0

# %%
# %matplotlib inline
data.resample('W').sum().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data.columns=['East','West']
data.resample('W').sum().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data['Total'] = data['West']+data['East']

ax=data.resample('D').sum().rolling(365).sum().plot()
ax.set_ylim(0,None);

# %%
data.groupby(data.index.time).mean().plot()
# Out:
# <Axes: xlabel='time'>

# %%
pivoted = data.pivot_table('Total',index = data.index.time,columns = data.index.date)
pivoted
# Out:
#           2012-10-03  2012-10-04  2012-10-05  2012-10-06  2012-10-07  \
# 00:00:00        13.0        18.0        11.0        15.0        11.0
# 01:00:00        10.0         3.0         8.0        15.0        17.0
# 02:00:00         2.0         9.0         7.0         9.0         3.0
# 03:00:00         5.0         3.0         4.0         3.0         6.0
# 04:00:00         7.0         8.0         9.0         5.0         3.0
# 05:00:00        31.0        26.0        25.0         5.0         9.0
# 06:00:00       155.0       142.0       105.0        27.0        17.0
# 07:00:00       352.0       319.0       319.0        33.0        26.0
# 08:00:00       437.0       418.0       370.0       105.0        69.0
# 09:00:00       276.0       241.0       212.0       114.0       103.0
# 10:00:00       118.0       120.0       119.0       115.0       108.0
# 11:00:00        42.0       108.0       104.0       124.0       165.0
# 12:00:00        76.0       104.0       101.0       164.0       191.0
# ...

# %%
pivoted.plot(legend = False, alpha = 0.01)
# Out:
# <Axes: xlabel='time'>

# %% [markdown]
# ## <span style="color:Blue">Prinicipal Component Analysis

# %%
X = pivoted.fillna(0).T.values
X.shape
# Out:
# (2159, 24)

# %%
from sklearn.decomposition import PCA
X2 = PCA(2, svd_solver='full').fit_transform(X)
X2.shape
# Out:
# (2159, 2)

# %%
plt.scatter(X2[:, 0], X2[:, 1]);

# %% [markdown]
# ## <span style="color:Blue">Unsupervised Clustering

# %%
gmm = GaussianMixture(2).fit(X)
labels = gmm.predict(X)

# %%
plt.scatter(X2[:, 0], X2[:, 1], c=labels, cmap='rainbow')
plt.colorbar();

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

pivoted.T[labels == 0].T.plot(legend=False, alpha=0.1, ax=ax[0]);
pivoted.T[labels == 1].T.plot(legend=False, alpha=0.1, ax=ax[1]);

ax[0].set_title('Purple Cluster')
ax[1].set_title('Red Cluster');

# %% [markdown]
# ## <span style="color:Blue">Comparing With Days Of Week

# %%
dayofweek = pd.DatetimeIndex(pivoted.columns).dayofweek
plt.scatter(X2[:, 0], X2[:, 1], c=dayofweek, cmap='rainbow')
plt.colorbar();

# %% [markdown]
# ## <span style="color:Blue">Analyzing Outliers

# %%
dates = pd.DatetimeIndex(pivoted.columns)
dates[(labels == 1) & (dayofweek < 5)]
# Out:
# DatetimeIndex(['2012-10-03', '2012-10-04', '2012-10-05', '2012-10-08',
#                '2012-10-09', '2012-10-10', '2012-10-11', '2012-10-12',
#                '2012-10-15', '2012-10-16',
#                ...
#                '2018-08-20', '2018-08-21', '2018-08-22', '2018-08-23',
#                '2018-08-24', '2018-08-27', '2018-08-28', '2018-08-29',
#                '2018-08-30', '2018-08-31'],
#               dtype='datetime64[ns]', length=1492, freq=None)
